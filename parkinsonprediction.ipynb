# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# C:\Users\PREODATOR HELIOS 300\AppData\Local\Temp\ipykernel_1640\1020607637.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
data=pd.read_csv('parkinson_dataset/parkinsons.csv')

# %%
data.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# ...

# %%
data.tail()
# Out:
#                name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 190  phon_R01_S50_2      174.188       230.978        94.261         0.00459
# 191  phon_R01_S50_3      209.516       253.017        89.488         0.00564
# 192  phon_R01_S50_4      174.688       240.005        74.287         0.01360
# 193  phon_R01_S50_5      198.764       396.961        74.904         0.00740
# 194  phon_R01_S50_6      214.289       260.277        77.973         0.00567
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 190           0.00003   0.00263   0.00259     0.00790       0.04087  ...
# 191           0.00003   0.00331   0.00292     0.00994       0.02751  ...
# 192           0.00008   0.00624   0.00564     0.01873       0.02308  ...
# 193           0.00004   0.00370   0.00390     0.01109       0.02296  ...
# 194           0.00003   0.00295   0.00317     0.00885       0.01884  ...
#
# ...

# %%
data.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   195.000000    195.000000    195.000000      195.000000
# mean    154.228641    197.104918    116.324631        0.006220
# std      41.390065     91.491548     43.521413        0.004848
# min      88.333000    102.145000     65.476000        0.001680
# 25%     117.572000    134.862500     84.291000        0.003460
# 50%     148.790000    175.829000    104.315000        0.004940
# 75%     182.769000    224.205500    140.018500        0.007365
# max     260.105000    592.030000    239.170000        0.033160
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        195.000000  195.000000  195.000000  195.000000    195.000000
# mean           0.000044    0.003306    0.003446    0.009920      0.029709
# std            0.000035    0.002968    0.002759    0.008903      0.018857
# min            0.000007    0.000680    0.000920    0.002040      0.009540
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              195 non-null    object
#  1   MDVP:Fo(Hz)       195 non-null    float64
#  2   MDVP:Fhi(Hz)      195 non-null    float64
#  3   MDVP:Flo(Hz)      195 non-null    float64
#  4   MDVP:Jitter(%)    195 non-null    float64
#  5   MDVP:Jitter(Abs)  195 non-null    float64
#  6   MDVP:RAP          195 non-null    float64
#  7   MDVP:PPQ          195 non-null    float64
#  8   Jitter:DDP        195 non-null    float64
#  9   MDVP:Shimmer      195 non-null    float64
#  10  MDVP:Shimmer(dB)  195 non-null    float64
#  11  Shimmer:APQ3      195 non-null    float64
#  12  Shimmer:APQ5      195 non-null    float64
#  13  MDVP:APQ          195 non-null    float64
#  14  Shimmer:DDA       195 non-null    float64
#  15  NHR               195 non-null    float64
# ...

# %%
data.isnull().sum()
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %%
data.shape
# Out:
# (195, 24)

# %%
data['status'].value_counts()
# Out:
# status
# 1    147
# 0     48
# Name: count, dtype: int64

# %%
data=data.drop(columns='name',axis=1)

# %%
data.head()
# Out:
#    MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  MDVP:Jitter(Abs)  \
# 0      119.992       157.302        74.997         0.00784           0.00007
# 1      122.400       148.650       113.819         0.00968           0.00008
# 2      116.682       131.111       111.555         0.01050           0.00009
# 3      116.676       137.871       111.366         0.00997           0.00009
# 4      116.014       141.781       110.655         0.01284           0.00011
#
#    MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  MDVP:Shimmer(dB)  ...  \
# 0   0.00370   0.00554     0.01109       0.04374             0.426  ...
# 1   0.00465   0.00696     0.01394       0.06134             0.626  ...
# 2   0.00544   0.00781     0.01633       0.05233             0.482  ...
# 3   0.00502   0.00698     0.01505       0.05492             0.517  ...
# 4   0.00655   0.00908     0.01966       0.06425             0.584  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# ...

# %%
fig,ax=plt.subplots(1,3,figsize=(16,10))
sns.boxplot(x='spread1',data=data,ax=ax[0],orient='v')
sns.boxplot(x='spread2',data=data,ax=ax[1],orient='v')
sns.boxplot(x='PPE',data=data,ax=ax[2],orient='v')
# Out:
# C:\Users\PREODATOR HELIOS 300\Desktop\python\Lib\site-packages\seaborn\_base.py:1608: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\Users\PREODATOR HELIOS 300\Desktop\python\Lib\site-packages\seaborn\_base.py:1608: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\Users\PREODATOR HELIOS 300\Desktop\python\Lib\site-packages\seaborn\_base.py:1608: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# <Axes: xlabel='PPE'>

# %%
fig,ax=plt.subplots(1,4,figsize=(16,10))
sns.boxplot(x='MDVP:Fo(Hz)',data=data,ax=ax[0],orient='v')
sns.boxplot(x='MDVP:Fhi(Hz)',data=data,ax=ax[1],orient='v')
sns.boxplot(x='MDVP:Flo(Hz)',data=data,ax=ax[2],orient='v')
sns.boxplot(x='MDVP:Jitter(%)',data=data,ax=ax[3],orient='v')
# Out:
# C:\Users\PREODATOR HELIOS 300\Desktop\python\Lib\site-packages\seaborn\_base.py:1608: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\Users\PREODATOR HELIOS 300\Desktop\python\Lib\site-packages\seaborn\_base.py:1608: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\Users\PREODATOR HELIOS 300\Desktop\python\Lib\site-packages\seaborn\_base.py:1608: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\Users\PREODATOR HELIOS 300\Desktop\python\Lib\site-packages\seaborn\_base.py:1608: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# <Axes: xlabel='MDVP:Jitter(%)'>

# %%
fig,ax=plt.subplots(1,2,figsize=(16,10))
sns.boxplot(x='NHR',data=data,ax=ax[0],orient='v')
sns.boxplot(x='HNR',data=data,ax=ax[1],orient='v')
# Out:
# C:\Users\PREODATOR HELIOS 300\Desktop\python\Lib\site-packages\seaborn\_base.py:1608: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\Users\PREODATOR HELIOS 300\Desktop\python\Lib\site-packages\seaborn\_base.py:1608: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# <Axes: xlabel='HNR'>

# %%
data.corr()
# Out:
#                   MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# MDVP:Fo(Hz)          1.000000      0.400985      0.596546       -0.118003
# MDVP:Fhi(Hz)         0.400985      1.000000      0.084951        0.102086
# MDVP:Flo(Hz)         0.596546      0.084951      1.000000       -0.139919
# MDVP:Jitter(%)      -0.118003      0.102086     -0.139919        1.000000
# MDVP:Jitter(Abs)    -0.382027     -0.029198     -0.277815        0.935714
# MDVP:RAP            -0.076194      0.097177     -0.100519        0.990276
# MDVP:PPQ            -0.112165      0.091126     -0.095828        0.974256
# Jitter:DDP          -0.076213      0.097150     -0.100488        0.990276
# MDVP:Shimmer        -0.098374      0.002281     -0.144543        0.769063
# MDVP:Shimmer(dB)    -0.073742      0.043465     -0.119089        0.804289
# Shimmer:APQ3        -0.094717     -0.003743     -0.150747        0.746625
# Shimmer:APQ5        -0.070682     -0.009997     -0.101095        0.725561
# ...

# %%
data=data.drop(columns=['MDVP:Jitter(Abs)','MDVP:RAP'],axis=1)

# %%
data.shape
# Out:
# (195, 21)

# %%
data.head()
# Out:
#    MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  MDVP:PPQ  \
# 0      119.992       157.302        74.997         0.00784   0.00554
# 1      122.400       148.650       113.819         0.00968   0.00696
# 2      116.682       131.111       111.555         0.01050   0.00781
# 3      116.676       137.871       111.366         0.00997   0.00698
# 4      116.014       141.781       110.655         0.01284   0.00908
#
#    Jitter:DDP  MDVP:Shimmer  MDVP:Shimmer(dB)  Shimmer:APQ3  Shimmer:APQ5  \
# 0     0.01109       0.04374             0.426       0.02182       0.03130
# 1     0.01394       0.06134             0.626       0.03134       0.04518
# 2     0.01633       0.05233             0.482       0.02757       0.03858
# 3     0.01505       0.05492             0.517       0.02924       0.04005
# 4     0.01966       0.06425             0.584       0.03490       0.04825
#
#    ...  Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# ...

# %%
data=data.drop(columns=['MDVP:PPQ','Jitter:DDP','MDVP:Shimmer(dB)','Shimmer:APQ3','Shimmer:APQ5','MDVP:APQ','Shimmer:DDA'],axis=1)

# %%
data.shape
# Out:
# (195, 14)

# %%
data.head()
# Out:
#    MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  MDVP:Shimmer  \
# 0      119.992       157.302        74.997         0.00784       0.04374
# 1      122.400       148.650       113.819         0.00968       0.06134
# 2      116.682       131.111       111.555         0.01050       0.05233
# 3      116.676       137.871       111.366         0.00997       0.05492
# 4      116.014       141.781       110.655         0.01284       0.06425
#
#        NHR     HNR  status      RPDE       DFA   spread1   spread2        D2  \
# 0  0.02211  21.033       1  0.414783  0.815285 -4.813031  0.266482  2.301442
# 1  0.01929  19.085       1  0.458359  0.819521 -4.075192  0.335590  2.486855
# 2  0.01309  20.651       1  0.429895  0.825288 -4.443179  0.311173  2.342259
# 3  0.01353  20.644       1  0.434969  0.819235 -4.117501  0.334147  2.405554
# 4  0.01767  19.649       1  0.417356  0.823484 -3.747787  0.234513  2.332180
#
#         PPE
# 0  0.284654
# 1  0.368674
# 2  0.332634
# ...

# %%
data=data.drop(columns=['PPE','NHR'],axis=1)

# %%
x=data.drop(columns='status',axis=1)
y=data['status']
print(x,y)
# Out:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  MDVP:Shimmer  \
# 0        119.992       157.302        74.997         0.00784       0.04374
# 1        122.400       148.650       113.819         0.00968       0.06134
# 2        116.682       131.111       111.555         0.01050       0.05233
# 3        116.676       137.871       111.366         0.00997       0.05492
# 4        116.014       141.781       110.655         0.01284       0.06425
# ..           ...           ...           ...             ...           ...
# 190      174.188       230.978        94.261         0.00459       0.04087
# 191      209.516       253.017        89.488         0.00564       0.02751
# 192      174.688       240.005        74.287         0.01360       0.02308
# 193      198.764       396.961        74.904         0.00740       0.02296
# 194      214.289       260.277        77.973         0.00567       0.01884
#
#         HNR      RPDE       DFA   spread1   spread2        D2
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
log_reg_model = LogisticRegression()
log_reg_model.fit(x_train, y_train)
# Out:
# C:\Users\PREODATOR HELIOS 300\Desktop\python\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = log_reg_model.predict(x_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy Score:", accuracy)
# Out:
# Accuracy Score: 0.8974358974358975

# %%
input_data=(198.764,	396.961,	74.904,	0.00740,	0.02296,	19.020,		0.451221,	0.643956,	-6.744577,	0.207454,	2.138608)
input_data_as_numpy_array=np.array(input_data)
input_data_reshaped=input_data_as_numpy_array.reshape(1,-1)

prediction=log_reg_model.predict(input_data_reshaped)
print(prediction)

if (prediction[0]== 0):
    print('Person has no parkinson disease')
else:
    print('Person has parkinson disease')
# Out:
# [0]
# Person has no parkinson disease
# C:\Users\PREODATOR HELIOS 300\Desktop\python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
data.tail()
# Out:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  MDVP:Shimmer  \
# 190      174.188       230.978        94.261         0.00459       0.04087
# 191      209.516       253.017        89.488         0.00564       0.02751
# 192      174.688       240.005        74.287         0.01360       0.02308
# 193      198.764       396.961        74.904         0.00740       0.02296
# 194      214.289       260.277        77.973         0.00567       0.01884
#
#         HNR  status      RPDE       DFA   spread1   spread2        D2
# 190  19.517       0  0.448439  0.657899 -6.538586  0.121952  2.657476
# 191  19.147       0  0.431674  0.683244 -6.195325  0.129303  2.784312
# 192  17.883       0  0.407567  0.655683 -6.787197  0.158453  2.679772
# 193  19.020       0  0.451221  0.643956 -6.744577  0.207454  2.138608
# 194  21.209       0  0.462803  0.664357 -5.724056  0.190667  2.555477

# %%
data.head()
# Out:
#    MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  MDVP:Shimmer  \
# 0      119.992       157.302        74.997         0.00784       0.04374
# 1      122.400       148.650       113.819         0.00968       0.06134
# 2      116.682       131.111       111.555         0.01050       0.05233
# 3      116.676       137.871       111.366         0.00997       0.05492
# 4      116.014       141.781       110.655         0.01284       0.06425
#
#       HNR  status      RPDE       DFA   spread1   spread2        D2
# 0  21.033       1  0.414783  0.815285 -4.813031  0.266482  2.301442
# 1  19.085       1  0.458359  0.819521 -4.075192  0.335590  2.486855
# 2  20.651       1  0.429895  0.825288 -4.443179  0.311173  2.342259
# 3  20.644       1  0.434969  0.819235 -4.117501  0.334147  2.405554
# 4  19.649       1  0.417356  0.823484 -3.747787  0.234513  2.332180

# %%
import pickle

# %%
filename='parkinson_model.sav'

# %%
pickle.dump(log_reg_model,open(filename,'wb'))
loaded_model=pickle.load(open('parkinson_model.sav','rb'))
